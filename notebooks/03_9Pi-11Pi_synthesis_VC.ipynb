# %% [markdown]
# # 03 · 9Pi-11Pi · synthesis · VC
#
# ## Path
# **VC = valid construction (GOS path)**
#
# This notebook continues the valid-construction path in the triplet-phase-lock framework.

# %% [markdown]
# ## Triplet
#
# $$\Pi^{(3)} = (9\Pi, 10\Pi, 11\Pi)$$
#
# - **9Pi** → stable synthesis
# - **10Pi** → extension across domains
# - **11Pi** → domain consistency (D)

# %% [markdown]
# ## ABCD overlay (valid construction)
#
# - **A = anchor**
# - **B = bilateral**
# - **C = constraint**
# - **D = domain consistency**
#
# For this VC notebook, the emphasis remains on **D**:
#
# - fractional and decimal consistency: $\frac{24}{25} = 0.96$
# - valid extension: $\sqrt{-1.96} = 1.4i$
# - magnitude: $|1.4i| = 1.4$

# %% [markdown]
# ## Core examples
#
# Consistent ratio:
#
# $$\frac{24}{25} = 0.96$$
#
# Valid extension:
#
# $$\sqrt{-1.96} = 1.4i$$
#
# Magnitude:
#
# $$|1.4i| = 1.4$$
#
# These are grouped as a progression from stable ratio into valid extension and domain-consistent synthesis.

# %% [markdown]
# ## Contrast (IA)
#
# - $2 = 0.96$
# - $2 = 0.96 = 1.4i$

# %%
ratio = 24 / 25
imag = complex(0, 1.4)
magnitude = abs(imag)

print('Ratio:', ratio)
print('Imaginary extension:', imag)
print('Magnitude:', magnitude)

# %% [markdown]
# ## Interpretation
#
# This notebook studies how valid construction accumulates into stable synthesis through extension and domain consistency.
