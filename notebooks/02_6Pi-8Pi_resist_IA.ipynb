# %% [markdown]
# # 02 · 6Pi-8Pi · resist · IA
#
# ## Path
# **IA = invalid assignment (ZOS path)**
#
# This notebook continues the invalid-assignment path in the triplet-phase-lock framework.

# %% [markdown]
# ## Triplet
#
# $$\Pi^{(2)} = (6\Pi, 7\Pi, 8\Pi)$$
#
# - **6Pi** → denial persistence (Z3)
# - **7Pi** → mismatch transition
# - **8Pi** → mixed inconsistency (Z4)

# %% [markdown]
# ## ZABCD overlay (invalid states)
#
# - **Z0 = unconstrained**
# - **Z1 = collapse**
# - **Z2 = assignment**
# - **Z3 = denial**
# - **Z4 = mixed inconsistency**
#
# For this IA notebook, the emphasis shifts to **Z3** and **Z4**:
#
# - denial: $2 = 0.96$
# - mixed inconsistency: incompatible forms

# %% [markdown]
# ## Core examples
#
# Denial:
#
# $$2 = 0.96$$
#
# Mixed comparison:
#
# $$1.4 \neq 1.4i$$
#
# These are grouped as a progression from denial into mixed inconsistency.

# %% [markdown]
# ## Contrast (VC)
#
# - $\frac{24}{25} = 0.96$
# - $\sqrt{-1.96} = 1.4i$
# - $|1.4i| = 1.4$

# %%
lhs = 2
rhs = 0.96
imag = complex(0,1.4)

print('Denial:', lhs == rhs)
print('Imag vs magnitude:', imag, abs(imag))

# %% [markdown]
# ## Interpretation
#
# This notebook studies how invalid assignment resists correction through denial and mixed inconsistency.
