# %% [markdown]
# # 01 · 3Pi-5Pi · extend · IA
#
# ## Path
# **IA = invalid assignment (ZOS path)**
#
# This notebook extends the invalid-assignment path in the triplet-phase-lock framework.

# %% [markdown]
# ## Triplet
#
# $$\Pi^{(1)} = (3\Pi, 4\Pi, 5\Pi)$$
#
# - **3Pi** → assignment drift (Z2)
# - **4Pi** → mismatch transition
# - **5Pi** → denial pattern (Z3)

# %% [markdown]
# ## ZABCD overlay (invalid states)
#
# - **Z0 = unconstrained**
# - **Z1 = collapse**
# - **Z2 = assignment**
# - **Z3 = denial**
# - **Z4 = mixed inconsistency**
#
# For this IA notebook, the emphasis shifts to **Z2** and **Z3**:
#
# - assignment: $0 \mapsto 0.96$
# - denial: $2 = 0.96$

# %% [markdown]
# ## Core examples
#
# Assignment:
#
# $$0 \mapsto 0.96$$
#
# Denial:
#
# $$2 = 0.96$$
#
# These are grouped as a progression from arbitrary reassignment into explicit domain mismatch.

# %% [markdown]
# ## Contrast (VC)
#
# - $2 = 1 + 1$
# - $\frac{25 - 1}{25} = \frac{24}{25}$

# %%
# Minimal IA examples for Triplet 1
assigned = 0.96
lhs = 2

print('Assignment:', f'0 -> {assigned}')
print('Denial candidate:', f'{lhs} = {assigned}')
print('Domain-consistent equality:', lhs == assigned)

# %% [markdown]
# ## Interpretation
#
# This notebook studies how invalid assignment extends by moving through:
#
# 1. an **assignment** without constraint
# 2. a **mismatch** between domains
# 3. an explicit **denial** of bilateral identity
#
# In later IA notebooks, this path extends to:
#
# - **Z4 = mixed inconsistency**
