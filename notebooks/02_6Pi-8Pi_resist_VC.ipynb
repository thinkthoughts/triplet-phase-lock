# %% [markdown]
# # 02 · 6Pi-8Pi · resist · VC
#
# ## Path
# **VC = valid construction (GOS path)**
#
# This notebook continues the valid-construction path in the triplet-phase-lock framework.

# %% [markdown]
# ## Triplet
#
# $$\Pi^{(2)} = (6\Pi, 7\Pi, 8\Pi)$$
#
# - **6Pi** → constraint transition (C)
# - **7Pi** → extension
# - **8Pi** → domain consistency (D)

# %% [markdown]
# ## ABCD overlay (valid construction)
#
# - **A = anchor**
# - **B = bilateral**
# - **C = constraint**
# - **D = domain consistency**
#
# Emphasis on **C** and **D**.

# %% [markdown]
# ## Core examples
#
# $$\frac{24}{25} = 0.96$$
#
# $$\sqrt{-1.96} = 1.4i$$
#
# $$|1.4i| = 1.4$$
#
# These form a consistent extension across domains.

# %% [markdown]
# ## Contrast (IA)
#
# - $2 = 0.96$
# - $1.4 \neq 1.4i$

# %%
ratio = 24/25
imag = complex(0,1.4)

print('Ratio:', ratio)
print('Magnitude:', abs(imag))

# %% [markdown]
# ## Interpretation
#
# This notebook studies how valid construction remains stable through constraint and domain consistency.
