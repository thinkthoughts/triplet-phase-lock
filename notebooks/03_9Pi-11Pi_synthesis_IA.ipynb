# %% [markdown]
# # 03 · 9Pi-11Pi · synthesis · IA
#
# ## Path
# **IA = invalid assignment (ZOS path)**
#
# This notebook continues the invalid-assignment path in the triplet-phase-lock framework.

# %% [markdown]
# ## Triplet
#
# $$\Pi^{(3)} = (9\Pi, 10\Pi, 11\Pi)$$
#
# - **9Pi** → unstable synthesis
# - **10Pi** → mismatch accumulation
# - **11Pi** → mixed inconsistency (Z4)

# %% [markdown]
# ## ZABCD overlay (invalid states)
#
# - **Z0 = unconstrained**
# - **Z1 = collapse**
# - **Z2 = assignment**
# - **Z3 = denial**
# - **Z4 = mixed inconsistency**
#
# For this IA notebook, the emphasis remains on **Z4**:
#
# - mixed inconsistency: incompatible forms treated as if they synthesize cleanly

# %% [markdown]
# ## Core examples
#
# Mixed comparison:
#
# $$2 \neq 0.96 \neq 1.4i$$
#
# Unstable synthesis:
#
# $$2 = 0.96 = 1.4i$$
#
# These are grouped as a progression from incompatible comparison into unstable synthesis.

# %% [markdown]
# ## Contrast (VC)
#
# - $\frac{24}{25} = 0.96$
# - $\sqrt{-1.96} = 1.4i$
# - $|1.4i| = 1.4$

# %%
lhs = 2
decimal = 0.96
imag = complex(0, 1.4)

print('Incompatible values:', lhs, decimal, imag)
print('lhs == decimal:', lhs == decimal)
print('decimal == imag:', decimal == imag)

# %% [markdown]
# ## Interpretation
#
# This notebook studies how invalid assignment accumulates into unstable synthesis through mixed inconsistency.
